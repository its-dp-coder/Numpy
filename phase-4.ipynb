# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1=np.array([[1,2,3], [4,5,6]])
array2=np.random.rand(3,3)
array3=np.zeros((3,4))

# %%
np.save('array1.npy', array1)
np.save('array2.npy', array2)
np.save('array3.npy', array3)

# %%
loaded_array1=np.load('array1.npy')
print(loaded_array1)

loaded_array2=np.load('array2.npy')
print(loaded_array2)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[0.5523145  0.42971633 0.07615425]
#  [0.92000017 0.0637805  0.56404528]
#  [0.12510038 0.42426667 0.07129077]]

# %%
try:
    logo = np.load('numpy-logo.npy')

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.imshow(logo)
    plt.title("Numpy Logo")
    plt.grid(False)
    dark_logo = 255 - logo

    plt.subplot(122)
    plt.imshow(dark_logo)
    plt.title("Numpy Dark Logo")
    plt.grid(False)

    plt.show()

except FileNotFoundError:
    print("Numpy logo file not found")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 19
#      15
#      16
#      17     plt.show()
#      18
# ---> 19 except FileNotFoundError:
#      20     print("Numpy logo file not found")
#
# File c:\Users\dps23\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_base.py:698, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     696 else:
#     697     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 698     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     699 if self._position.width < 0 or self._position.height < 0:
#     700     raise ValueError('Width and height specified must be non-negative')
#
# File c:\Users\dps23\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\gridspec.py:586, in SubplotSpec._from_subplot_args(figure, args)
#     584     rows, cols, num = args
#     585 else:
# --> 586     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     588 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     589 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 0 were given
